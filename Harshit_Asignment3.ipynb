# %%
import pandas as pd

# %%
data = pd.read_csv('C:\\Users\\HARSHIT.K\\Documents\\data.csv')

# %%
data
# Out:
#            Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# 0        5/2/10        42.31       2.572        NaN        NaN        NaN
# 1       12/2/10        38.51       2.548        NaN        NaN        NaN
# 2    19/02/2010        39.93       2.514        NaN        NaN        NaN
# 3    26/02/2010        46.63       2.561        NaN        NaN        NaN
# 4        5/3/10        46.50       2.625        NaN        NaN        NaN
# ..          ...          ...         ...        ...        ...        ...
# 138  28/09/2012        76.08       3.666    3666.27       7.64       1.65
# 139     5/10/12        68.55       3.617    8077.89        NaN      18.22
# 140    12/10/12        62.99       3.601    2086.18        NaN       8.11
# 141  19/10/2012        67.97       3.594     950.33        NaN       4.93
# 142  26/10/2012        69.16       3.506    2585.85      31.75       6.00
#
#      MarkDown4  MarkDown5         CPI  Unemployment     Day type  \
# ...

# %%
import matplotlib.pyplot as plt
plt.style.use("dark_background")

# %%
data.isna()
# Out:
#       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# 0    False        False       False       True       True       True
# 1    False        False       False       True       True       True
# 2    False        False       False       True       True       True
# 3    False        False       False       True       True       True
# 4    False        False       False       True       True       True
# ..     ...          ...         ...        ...        ...        ...
# 138  False        False       False      False      False      False
# 139  False        False       False      False       True      False
# 140  False        False       False      False       True      False
# 141  False        False       False      False       True      False
# 142  False        False       False      False      False      False
#
#      MarkDown4  MarkDown5    CPI  Unemployment  Day type  dept_1 sales  \
# ...

# %%
data.dropna()
# Out:
#            Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# 92     11/11/11        59.11       3.297   10382.90    6115.67     215.07
# 93   18/11/2011        62.25       3.308    6074.12     254.39      51.98
# 94   25/11/2011        60.14       3.236     410.31      98.00   55805.51
# 95      2/12/11        48.91       3.172    5629.51      68.00    1398.11
# 96      9/12/11        43.93       3.158    4640.65      19.00     105.02
# 97   16/12/2011        51.63       3.159    5011.32      67.00     347.37
# 98   23/12/2011        47.96       3.112    2725.36      40.48     634.70
# 99   30/12/2011        44.55       3.129    5762.10   46011.38     260.36
# 100      6/1/12        49.01       3.157    6277.39   21813.16     143.10
# 101  13/01/2012        48.53       3.261    5183.29    8025.87      42.24
# 102  20/01/2012        54.11       3.268    4139.87    2807.19      33.88
# 103  27/01/2012        54.26       3.290    1164.46    1082.74      44.00
# ...

# %%
data.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.plot.bar()
# Out:
# <AxesSubplot:>

# %%
data.plot()
# Out:
# <AxesSubplot:>

# %%
data.plot.area()
# Out:
# <AxesSubplot:>

# %%
data.plot.scatter("Date","Temperature")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Temperature'>
